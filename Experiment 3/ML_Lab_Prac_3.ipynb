# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install numpy pandas matplotlib seaborn scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
#Load iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
#Load iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)
iris.target_names
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
np.random.seed(42)

# %%
# Introduce missing values
df.iloc[0, 0] = np.nan  # First row, first column ('Tax')
df.iloc[1, 0] = np.nan  # Second row, first column ('Tax')
df.iloc[2, 0] = np.nan  # Third row, first column ('Tax')

# Show the DataFrame
print(df.head(10))
# Out:
#      Tax
# 0    NaN
# 1    NaN
# 2    NaN
# 3  130.0
# 4  150.0
# 5  180.0
# 6  200.0
# 7  220.0
# 8  250.0
# 9  400.0

# %%
df_filled = df.fillna(df.mean(numeric_only=True))

# %%
tax_values = [0,100,120,130,150,180,200,220,250,400]

# %%
df = pd.DataFrame({'Tax': tax_values})

# %%
sns.boxplot(data=df, orient="h")
plt.title("Box Plot of Tax Values")
plt.ylabel("Tax")
plt.show()

# %%
df.describe()
# Out:
#               Tax
# count   10.000000
# mean   175.000000
# std    105.856297
# min      0.000000
# 25%    122.500000
# 50%    165.000000
# 75%    215.000000
# max    400.000000

# %%
print(df.head(10))
# Out:
#    Tax
# 0    0
# 1  100
# 2  120
# 3  130
# 4  150
# 5  180
# 6  200
# 7  220
# 8  250
# 9  400
